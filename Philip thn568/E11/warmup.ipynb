# %%
# Warmup
def TnFactory(n):
    if n==0:
        def helper(x):
            return 1
    if n==1:
        def helper(x):
            return n
    if n>=2:
        def helper(x):
            return 2*x*TnFactory(n-1)(x)-TnFactory(n-2)(x)
    return helper

# %%
x.shape
# Out:
# (100,)

# %%
import numpy as np
import matplotlib.pyplot as plt

#plotting on [-1,-10/11] and 20 instead of 5 because it's prettier!
steps=100
antal=20
x=np.linspace(-1,-10/11,steps)
fix,ax=plt.subplots()
for i in range(1,antal):
    if i==1:
        ax.plot(x,np.ones(steps))
    else: 
        ax.plot(x,TnFactory(i)(x))
