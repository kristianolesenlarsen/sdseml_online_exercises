# %%
from scipy import integrate
from numpy import log, linspace
import matplotlib.pyplot as plt

# %%
def Integrate(f,a,b):
    I,_=integrate.quad(f,a,b)
    return I

# %%
values=linspace(10,10**10,100)
x2=lambda x:1/log(x)
li=list(Integrate(x2,2,i) for i in values)

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.style.use('seaborn-dark-palette')
plt.plot(values,li,label='Logarithmic integrate')
plt.legend()
plt.xlabel('values')
plt.show()

# %% [markdown]
# # Week 9: Networks 1

# %% [markdown]
# A network is a way to represent a system of things that interact or are interrelated in some fashion. It could just be your facebook network, that's obvious, but a network can also represent the interaction patterns of proteins in the human body, who votes what on whose bill in the US Senate, the mutually attractive forces between galaxies in the universe or just about anything else that you can possibly imagine. This week we will get started on some of the fundamental concepts, and then look closer at some Facebook data. In the exercises today you will:
#
# * Get warmed up to thinking about systems as networks
# * Learn to use the `NetworkX` library
# * Explore a Facebook network

# %% [markdown]
# # Lecture

# %%
# ----------------- !
# Execute this cell !
# ----------------- !

from IPython.display import HTML

def video_html(url):
    return f"""
    <div align="middle">
    <video width="50%" controls>
      <source src="{url}" type="video/mp4">
    </video></div>"""

HTML(video_html('https://www.dropbox.com/s/43ya0a9jmaa6exk/slides_week9_mov.m4v?raw=1'))

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import networkx as nx           # pip install networkx
import pandas as pd
from collections import Counter
from netwulf import visualize   # pip install netwulf
import numpy as np

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Part 0: Networks

# %% [markdown]
# Questions for chapter 1 and 2 of [Network Science](http://barabasi.com/networksciencebook/).

# %% [markdown]
# > **Ex. 5.0.1**: List three different real networks and state the nodes and links for each of them.

# %% [markdown]
# Citations networks: articles, cited relations
# Power grid: power plans, cables
# Actor networks: actors, co-acting

# %% [markdown]
# > **Ex. 5.0.2**: What networks are you personally most interested in. Address the following questions:
# >   * What are its nodes and links?
# >   * How large is it?
# >   * Can be mapped out?
# >   * Why do you care about it?

# %% [markdown]
# Science collaboration: scientists are nodes, co-authoships are links, it is really large and can be mapped.

# %% [markdown]
# > **Ex. 5.0.3**: In your view what would be the area where network science could have the biggest impact in the next decade? Explain your answer - and base it on the text in the book.

# %% [markdown]
# Epidemics, now we are going through the COVID-19 pandemic. With network science, we could model and predict the spread of virus, which helps us to find and take actions to contain the virus like social disctancing.

# %% [markdown]
# > **Ex. 5.0.4**: Section 2.5 states that real networks are sparse. Can you think of a real network where each node has *many* connections? Is that network still sparse? If yes, can you explain why?

# %% [markdown]
# The actor network in the book. There are 702,388 nodes and 29,397,908 links in the actor network. It is still sparse, because L‹‹ Lmax, Lmax is 246,674,100,078.

# %% [markdown]
# ### Part 1: The `NetworkX` library

# %% [markdown]
# `NetworkX` is the Python library we will be using for working with networks. It should come installed with your Anaconda distribution, but you wont know how to use it yet. The best way to get familiar is to work through a tutorial. That's what the following exercises are about.

# %% [markdown]
# > **Ex. 5.1.1**: Go to the `NetworkX` project's [tutorial page](https://networkx.github.io/documentation/stable/tutorial/index.html). Read the first few sections about nodes, edges and attributes. Write an example below where you create a graph, `G`, and then:
# 1. add some nodes and edges to,
# 2. print its nodes and edges
# 3. delete a node, and
# 4. plot it.

# %%
import networkx as nx
G=nx.Graph()
G.add_node(1)
G.add_edge(1, 2)
G.add_edges_from([(2, 3),(3,4),(4,2),(5,4)])

# %%
G.nodes
# Out:
# NodeView((1, 2, 3, 4, 5))

# %%
G.edges
# Out:
# EdgeView([(1, 2), (2, 3), (2, 4), (3, 4), (4, 5)])

# %%
G.remove_node(1)

# %%
import matplotlib.pyplot as plt
nx.draw(G, with_labels=True)

# %% [markdown]
# > **Ex. 5.1.2**: `NetworkX` has lots of functions to generate synthetic networks. One of the most famous types of synthetic networks is called an Erdős–Rényi (ER) network.
# 1. Describe what an ER network is and how to create one.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-1.10/reference/generators.html), find a method you can use for generating an ER network. Create one with $N=100$ nodes and probability of edge creation $p=0.1$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created ER graph.
#     * A node's *degree* is the number of other nodes it is connected to.
#     * The *degree distribution* is a histogram which shows the distribution of node degrees.

# %%
import networkx as nx
G2 = nx.erdos_renyi_graph(100,0.1)

# %%
nx.draw(G2,node_size=40)

# %%
def plot_degree_distribution(G):
    degrees=[i[1] for i in G.degree]
    a= np.arange(min(degrees),max(degrees)+1)
    hist=np.histogram(degrees,a)
    bins=a[:-1]+(a[1]-a[0])/2
    plt.bar(bins,hist[0],color='grey')
    plt.xlabel('Degrees')
    plt.ylabel('Count')
    plt.title('Degree ditribution')
    plt.show()

# %%
plot_degree_distribution(G2)

# %% [markdown]
# > **Ex. 4.1.3**: Another very famous type of synthetic network is the Barabási–Albert (BA) network.
# 1. Describe what a BA network is and how to create one.
# 2. On the [`NetworkX` documentations site](https://networkx.github.io/documentation/networkx-1.10/reference/generators.html), find a method you can use for generating a BA network. Create one with $N=100$ nodes and number of new edges from each new node $m=2$.
# 3. Plot the network
# 4. Visualize the [degree distribution](https://en.wikipedia.org/wiki/Degree_distribution) of your newly created BA graph.
# 5. Explain the main difference(s) you observe, when comparing to the ER network.
# 6. Are there other measures we could have used to describe the ER and BA networks further?

# %%
G3=nx.barabasi_albert_graph(100,2)

# %%
nx.draw(G3,node_size=40)

# %%
plot_degree_distribution(G3)

# %% [markdown]
# Erdős–Rényi (ER) network is the random network where each pair of n labeled nodes is connected with probability p.
#
# Barabási–Albert (BA) network is based on two mechanisms, growth, new nodes coming all the time and they link to the existing network, and preferential attachment, new nodes connect to the nodes that already have a lot of connections. In such a way, the probability of linking to a node is proportional to its degree.
#
# The degree distribution of Erdős–Rényi (ER) network follows the binomial/Poisson distribution. On the other hand, the degree distribution of Barabási–Albert (BA) network is heavy-tailed, which follows a power law. Some nodes have a lot of connections while most of the nodes have few connections.

# %% [markdown]
# ### Part 2: Facebook network

# %% [markdown]
# Now that you know how to build a network in `NetworkX`, visualize it and plot some statistics, you are ready to analyze today's dataset. We will be using [this facebook dataset](http://socialnetworks.mpi-sws.org/data-wosn2009.html) collected by the researchers at the Max Planck Institute. Go ahead and download the list of wall posts. Put the file in the same directory as this notebook and load it like:

# %%
data = pd.read_csv(
    "facebook-wall.txt.gz",
    delimiter="\t",
    header=None,
    names=['user1', 'user2', 'timestamp']
)

data.head(10)
# Out:
#    user1  user2   timestamp
# 0     28     28  1095135831
# 1   1015   1017  1097725406
# 2    959    959  1098387569
# 3    991    991  1098425204
# 4   1015   1017  1098489762
# 5   1015   1017  1098673897
# 6   3368   3368  1098755376
# 7  14752  14736  1099526971
# 8   1015   1017  1099602800
# 9   1531   1080  1099889279

# %% [markdown]
# As you can see this is a *temporal network* (in that edges are timestamped). Time is given in UNIX timestamps. Though there are ways to model such
# a network in its entire complexity, we'll start simple and just take a slice of it out and treat that as a static
# network. You can create a `nx.DiGraph` from a slice of time like:

# %%
t0 = data.timestamp.max() - 86400 * 7  # Lower bound of time-slice (here: 7 days before last wall post)
t1 = data.timestamp.max()              # Upper bound of time-slice

# Subset of the pandas dataframe
data_t = data.loc[data.timestamp.between(t0, t1)]

# Count the number of times each link occurs and store that in a new 'weight' column
data_t = data_t.groupby(['user1', 'user2']).size().reset_index(name='weight')

# Create a `nx.DiGraph` from this dataframe
G_t = nx.from_pandas_edgelist(data_t, 'user1', 'user2', 'weight', create_using=nx.DiGraph)

# %% [markdown]
# > **Ex: 5.2.1**: Convert the above sample code into a function where you can easily input `t0` and `t1` of the slice, and get a `nx.DiGraph` in return. Create the aggregated network for the last 365 days of the data. Print the number of nodes and edges.

# %%
def network(t0,t1):
    # Subset of the pandas dataframe
    data_t = data.loc[data.timestamp.between(t0, t1)]

    # Count the number of times each link occurs and store that in a new 'weight' column
    data_t = data_t.groupby(['user1', 'user2']).size().reset_index(name='weight')

    # Create a `nx.DiGraph` from this dataframe
    G_t = nx.from_pandas_edgelist(data_t, 'user1', 'user2', 'weight', create_using=nx.DiGraph)
    return G_t

# %%
G4=network(data.timestamp.min(),data.timestamp.max())

# %%
G4.number_of_edges()
# Out:
# 274086

# %%
G4.number_of_nodes()
# Out:
# 46952

# %% [markdown]
# > **Ex: 5.2.2**: Since it's a directed network, there are two degree distributions we can plot: one for the
# in-degrees and another for the out-degrees. Plot them both in the same figure (remember to add a legend).
# The distribution is very heavy-tailed, so you may want to log-scale both axes. Comment on the result. Does
# it resemble any of the network models you know?
# >
# > *Hint: use `Counter` to count how many times each degree-value occurs and then scatter plot the degree-values
# against counts. When you log-scale the axes, zero values cause trouble, so you should remove the data point for
# degree 0.*

# %%
def hist(degree):
    v= np.arange(min(degree),max(degree)+1)
    d=np.histogram(degree,v)
    return v,d

# %%
in_degrees=[G4.in_degree(n) for n in G4.nodes()]
out_degrees=[G4.out_degree(n) for n in G4.nodes()]
v,d=hist(in_degrees)
v_1,d_1=hist(out_degrees)
plt.scatter(v[:-1]+(v[1]-v[0])/2,d[0]/len(in_degrees),s=5,label='In degrees')
plt.scatter(v_1[:-1]+(v_1[1]-v_1[0])/2,d_1[0]/len(out_degrees),s=5,label='Out degrees')
plt.xlabel('Degrees')
plt.ylabel('p')
plt.legend()
plt.title('Degree ditribution')
plt.show()

# %%
plt.loglog(v[:-1]+(v[1]-v[0])/2,d[0]/len(in_degrees),'o',label='In degrees')
plt.loglog(v_1[:-1]+(v_1[1]-v_1[0])/2,d_1[0]/len(out_degrees),'o',label='Out degrees')
plt.xlabel('Degrees')
plt.ylabel('p')
plt.legend()
plt.xlim(left=1)
plt.title('Degree ditribution')
plt.show()

# %% [markdown]
# > **Ex: 5.2.3**: Using a histogram plot the distribution of (weighted) local clustering coefficients ([docs](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.cluster.clustering.html#networkx.algorithms.cluster.clustering)). Which distribution does it appear to follow?
# >
# > *Hint: figure out how to plot a histogram with logarithmic bins.*

# %%
cluster=list(nx.clustering(G4).values())

# %%
# power law
hist=np.histogram(cluster,50)
plt.loglog(hist[1][:-1],hist[0])
plt.xlabel('Clustering coefficients')
plt.ylabel('Count')
plt.title('The ditribution of clustering coefficients')
plt.show()

# %% [markdown]
# We want to plot the network so we can visually get a feeling for how people are connected. `networkx`'s `nx.draw` method won't cut it here, it's too slow and has bad layout support for large networks, so instead we'll use `netwulf` ([docs](https://netwulf.readthedocs.io/)) to visualize networks in a browser-app I made (still in beta, bugs may occur). But even with this tool, the network of one year is still too big to make nice visualizations, so we have to reduce the number of links and nodes by some heuristic. This could for example be to threshold link weight to reduce the number of links, thresholding weighted node degree (or other relevant metrics).

# %% [markdown]
# > **Ex: 5.2.4**: Threshold the network by some meaningful heuristic so it has around 5000 nodes and 20000 edges. Then launch a visualization of it using `netwulf`, style the network so it looks nice and download (or screenshot) the figure and put it into the cell below. State explicitly what thresholds you apply and why you think they make sense. Comment on the result. Do you see anything interesting in this network or is it just a big hairball?
# >
# > *Hint: The longer you let the nodes **wiggle** the nicer the network will look.*

# %%
count=Counter(G4.in_degree(n) for n in G4.nodes())

# %%
count.most_common
# Out:
# <bound method Counter.most_common of Counter({1: 10585, 0: 6966, 2: 6039, 3: 4137, 4: 3049, 5: 2217, 6: 1789, 7: 1470, 8: 1223, 9: 1061, 10: 882, 11: 747, 12: 718, 13: 587, 14: 535, 15: 460, 16: 448, 17: 353, 18: 295, 19: 288, 20: 276, 21: 231, 22: 228, 23: 198, 25: 160, 24: 149, 26: 146, 27: 123, 28: 108, 29: 103, 30: 94, 31: 91, 32: 81, 33: 81, 36: 80, 35: 68, 34: 59, 37: 55, 39: 53, 44: 44, 38: 38, 40: 37, 43: 34, 42: 34, 41: 32, 45: 29, 47: 29, 46: 26, 48: 24, 50: 22, 56: 20, 51: 20, 53: 18, 49: 17, 52: 16, 57: 16, 59: 14, 58: 14, 55: 13, 61: 12, 60: 12, 64: 10, 62: 10, 76: 9, 54: 9, 73: 8, 72: 7, 69: 7, 70: 7, 78: 6, 74: 6, 67: 6, 77: 6, 71: 6, 66: 6, 80: 5, 63: 5, 84: 5, 93: 5, 68: 5, 85: 5, 82: 5, 98: 4, 75: 3, 101: 3, 117: 3, 91: 3, 102: 3, 97: 3, 88: 2, 150: 2, 145: 2, 113: 2, 65: 2, 96: 2, 81: 2, 79: 2, 105: 2, 103: 2, 90: 1, 154: 1, 109: 1, 112: 1, 83: 1, 129: 1, 199: 1, 100: 1, 89: 1, 120: 1, 147: 1, 119: 1, 161: 1, 94: 1, 87: 1, 114: 1, 110: 1, 104: 1})>

# %%
for node in list(G4.nodes()):
    if G4.in_degree(node)<2:
        G4.remove_node(node)
    else:
        pass

# %%
for edge in list(G4.edges()):
    if G4.get_edge_data(*edge)['weight']<5:
        G4.remove_edge(*edge)

# %%
G4.number_of_edges()
# Out:
# 21564

# %%
G4.number_of_nodes()
# Out:
# 5189

# %%
visualize(G4)
# Out:
# ({'xlim': [0, 549],
#   'ylim': [0, 549],
#   'linkColor': '#7c7c7c',
#   'linkAlpha': 0.5,
#   'nodeStrokeColor': '#555555',
#   'nodeStrokeWidth': 0.2831253394279507,
#   'links': [{'source': 1639,
#     'target': 1639,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 1639,
#     'target': 3290,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 1639,
#     'target': 3819,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 1639,
#     'target': 3824,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 1639, 'target': 3827, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 309, 'target': 71, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 309, 'target': 1990, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 309, 'target': 2321, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 309, 'target': 2412, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 309, 'target': 3904, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 309, 'target': 7590, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 449, 'target': 358, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 449, 'target': 450, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 449, 'target': 2294, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 449, 'target': 2335, 'width': 0.19701273099093555, 'weight': 20},
#    {'source': 449, 'target': 3076, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 449, 'target': 5403, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 449, 'target': 5406, 'width': 0.2606233456578416, 'weight': 35},
#    {'source': 449, 'target': 5423, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 449, 'target': 5438, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 449, 'target': 9686, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 449, 'target': 18031, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 449,
#     'target': 18036,
#     'width': 0.26796628504186387,
#     'weight': 37},
#    {'source': 571, 'target': 90, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 571, 'target': 125, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 571, 'target': 407, 'width': 0.27156330887614916, 'weight': 38},
#    {'source': 571, 'target': 608, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 571, 'target': 797, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 571, 'target': 802, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 640, 'target': 1435, 'width': 0.13930903806377162, 'weight': 10},
#    {'source': 640, 'target': 2238, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 640, 'target': 13033, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 2138, 'target': 1126, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 2138,
#     'target': 2120,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 2138, 'target': 2143, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 2138, 'target': 2149, 'width': 0.215816633758865, 'weight': 24},
#    {'source': 2138,
#     'target': 2151,
#     'width': 0.19202425722778202,
#     'weight': 19},
#    {'source': 2138,
#     'target': 2154,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 4295, 'target': 530, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 4295, 'target': 2412, 'width': 0.3605925043284976, 'weight': 67},
#    {'source': 4295, 'target': 11705, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 4295,
#     'target': 15283,
#     'width': 0.2888773697797899,
#     'weight': 43},
#    {'source': 4295, 'target': 15821, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 4295, 'target': 21652, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 12375, 'target': 36, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 12375,
#     'target': 4140,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 12375, 'target': 5462, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 15, 'target': 1207, 'width': 0.17621354357144456, 'weight': 16},
#    {'source': 15, 'target': 1749, 'width': 0.13930903806377162, 'weight': 10},
#    {'source': 15, 'target': 1922, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 15, 'target': 16169, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 14, 'target': 14, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 14, 'target': 3663, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 14, 'target': 6264, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 14, 'target': 7576, 'width': 0.13930903806377162, 'weight': 10},
#    {'source': 14, 'target': 7743, 'width': 0.449258148615064, 'weight': 104},
#    {'source': 14, 'target': 11268, 'width': 0.215816633758865, 'weight': 24},
#    {'source': 14, 'target': 11273, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 14, 'target': 11680, 'width': 0.1648326767384268, 'weight': 14},
#    {'source': 14, 'target': 11784, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 14, 'target': 13008, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 14, 'target': 16561, 'width': 0.25687317394632986, 'weight': 34},
#    {'source': 14, 'target': 19062, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 14, 'target': 22345, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 14, 'target': 23104, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 14, 'target': 26853, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 132, 'target': 126, 'width': 0.215816633758865, 'weight': 24},
#    {'source': 132, 'target': 429, 'width': 0.3267086538100782, 'weight': 55},
#    {'source': 132, 'target': 3610, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 132, 'target': 3633, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 132, 'target': 5182, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 132, 'target': 10884, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 132, 'target': 11676, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 132, 'target': 12970, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 1899, 'target': 449, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 1899,
#     'target': 1898,
#     'width': 0.17621354357144456,
#     'weight': 16},
#    {'source': 1899, 'target': 5405, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 1899, 'target': 5419, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 1899,
#     'target': 10891,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 1899,
#     'target': 13425,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 1928,
#     'target': 1916,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 1928, 'target': 3579, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 1928, 'target': 5438, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 1928, 'target': 6264, 'width': 0.2643203153571668, 'weight': 36},
#    {'source': 1928,
#     'target': 8116,
#     'width': 0.41559881131646054,
#     'weight': 89},
#    {'source': 1928, 'target': 8123, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 1928, 'target': 8129, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 1928, 'target': 8405, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 1928, 'target': 8410, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 1928,
#     'target': 12969,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 1928, 'target': 12972, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 1928,
#     'target': 13003,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 1928,
#     'target': 13011,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 1928, 'target': 16527, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 1928, 'target': 18472, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 1928, 'target': 25751, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 3663, 'target': 8617, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 3663,
#     'target': 12274,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 3663,
#     'target': 19569,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 3663,
#     'target': 22297,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 3691, 'target': 3630, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 3691,
#     'target': 3720,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 3691,
#     'target': 10264,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 3691,
#     'target': 18650,
#     'width': 0.45993085147678636,
#     'weight': 109},
#    {'source': 3691,
#     'target': 19519,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 3691, 'target': 20759, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 3691, 'target': 25082, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 3691, 'target': 28979, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 3691,
#     'target': 31255,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 3691,
#     'target': 33545,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 3691,
#     'target': 36739,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 3732, 'target': 14, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 3732, 'target': 9720, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 3732, 'target': 9741, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 3732,
#     'target': 10155,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 3732, 'target': 22352, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 3732,
#     'target': 25672,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 3732,
#     'target': 28547,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 4374, 'target': 133, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 4374,
#     'target': 1905,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 4374,
#     'target': 1944,
#     'width': 0.17621354357144456,
#     'weight': 16},
#    {'source': 4374,
#     'target': 3602,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 4374, 'target': 4374, 'width': 0.1648326767384268, 'weight': 14},
#    {'source': 4374,
#     'target': 5013,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 4374,
#     'target': 5188,
#     'width': 0.17621354357144456,
#     'weight': 16},
#    {'source': 4374, 'target': 7510, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 4374,
#     'target': 8414,
#     'width': 0.28549857085853186,
#     'weight': 42},
#    {'source': 4374,
#     'target': 8885,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 4374, 'target': 9838, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 4374, 'target': 9875, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 4374, 'target': 9879, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 4374, 'target': 9884, 'width': 0.2372347433453514, 'weight': 29},
#    {'source': 4374,
#     'target': 9897,
#     'width': 0.21127261677364328,
#     'weight': 23},
#    {'source': 4374,
#     'target': 9909,
#     'width': 0.21127261677364328,
#     'weight': 23},
#    {'source': 4374,
#     'target': 10130,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 4374, 'target': 10333, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 4374,
#     'target': 10340,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 4374,
#     'target': 10470,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 4374,
#     'target': 11795,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 4374,
#     'target': 13494,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 4374,
#     'target': 14120,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 4374,
#     'target': 14660,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 4374,
#     'target': 16675,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 4374,
#     'target': 19105,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 4374,
#     'target': 19526,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 4374, 'target': 19549, 'width': 0.27511330672359, 'weight': 39},
#    {'source': 4374,
#     'target': 22342,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 4374,
#     'target': 28443,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 4374,
#     'target': 32505,
#     'width': 0.24527887203627102,
#     'weight': 31},
#    {'source': 5157, 'target': 433, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 5157, 'target': 3639, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 5157,
#     'target': 3666,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 5157,
#     'target': 5128,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 5157, 'target': 5157, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 5157,
#     'target': 7580,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 5157, 'target': 10891, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 5157,
#     'target': 13007,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 5157,
#     'target': 13484,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 5157,
#     'target': 14098,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 5157, 'target': 16572, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 5157,
#     'target': 19485,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 5157,
#     'target': 19526,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 5157, 'target': 26923, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6261, 'target': 133, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 6261, 'target': 429, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6261, 'target': 432, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6261, 'target': 543, 'width': 0.13930903806377162, 'weight': 10},
#    {'source': 6261, 'target': 1904, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 6261, 'target': 3606, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 6261, 'target': 3873, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 6261, 'target': 5043, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 6261, 'target': 6266, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 6261, 'target': 8116, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 6261, 'target': 8119, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 6261,
#     'target': 8653,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 6261, 'target': 9215, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 6261,
#     'target': 10131,
#     'width': 0.19202425722778202,
#     'weight': 19},
#    {'source': 6261,
#     'target': 10891,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 6261,
#     'target': 11028,
#     'width': 0.30521081044749404,
#     'weight': 48},
#    {'source': 6261,
#     'target': 11498,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 6261, 'target': 14082, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6261, 'target': 14873, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6261,
#     'target': 14882,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 6261,
#     'target': 19469,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 6261,
#     'target': 19505,
#     'width': 0.20662869546545903,
#     'weight': 22},
#    {'source': 6261,
#     'target': 24372,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 6264, 'target': 14, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 6264,
#     'target': 1928,
#     'width': 0.30201479765963585,
#     'weight': 47},
#    {'source': 6264,
#     'target': 3728,
#     'width': 0.34406794289230946,
#     'weight': 61},
#    {'source': 6264, 'target': 5128, 'width': 0.224629074307532, 'weight': 26},
#    {'source': 6264, 'target': 5438, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 6264,
#     'target': 8116,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 6264, 'target': 8129, 'width': 0.2643203153571668, 'weight': 36},
#    {'source': 6264, 'target': 8131, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 6264,
#     'target': 10898,
#     'width': 0.4202425175834849,
#     'weight': 91},
#    {'source': 6264, 'target': 11820, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6264,
#     'target': 12972,
#     'width': 0.19701273099093555,
#     'weight': 20},
#    {'source': 6264, 'target': 12976, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 6264,
#     'target': 12991,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 6264,
#     'target': 13011,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 6264,
#     'target': 18472,
#     'width': 0.31460410238884706,
#     'weight': 51},
#    {'source': 6264,
#     'target': 23118,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 6264,
#     'target': 34731,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 7576, 'target': 14, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 7576, 'target': 574, 'width': 0.3296653534768536, 'weight': 56},
#    {'source': 7576,
#     'target': 3736,
#     'width': 0.19202425722778202,
#     'weight': 19},
#    {'source': 7576, 'target': 5058, 'width': 0.2888773697797899, 'weight': 43},
#    {'source': 7576,
#     'target': 7540,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 7576, 'target': 7576, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 7576, 'target': 9826, 'width': 0.2643203153571668, 'weight': 36},
#    {'source': 7576, 'target': 9869, 'width': 0.1869026873944194, 'weight': 18},
#    {'source': 7576,
#     'target': 10131,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 7576, 'target': 10898, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 7576,
#     'target': 14236,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 7583, 'target': 105, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 7583, 'target': 151, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 7583, 'target': 441, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 7583, 'target': 443, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 7583,
#     'target': 1917,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 7583,
#     'target': 3600,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 7583,
#     'target': 3728,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 7583,
#     'target': 3993,
#     'width': 0.24527887203627102,
#     'weight': 31},
#    {'source': 7583,
#     'target': 5128,
#     'width': 0.24129033187999907,
#     'weight': 30},
#    {'source': 7583, 'target': 7583, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 7583, 'target': 7743, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 7583,
#     'target': 8137,
#     'width': 0.19202425722778202,
#     'weight': 19},
#    {'source': 7583, 'target': 8600, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 7583,
#     'target': 8651,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 7583,
#     'target': 10884,
#     'width': 0.2606233456578416,
#     'weight': 35},
#    {'source': 7583,
#     'target': 10885,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 7583,
#     'target': 11315,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 7583,
#     'target': 11324,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 7583,
#     'target': 11535,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 7583,
#     'target': 11554,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 7583, 'target': 12319, 'width': 0.215816633758865, 'weight': 24},
#    {'source': 7583,
#     'target': 12970,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 7583, 'target': 13001, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 7583, 'target': 19479, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 7583,
#     'target': 22345,
#     'width': 0.20662869546545903,
#     'weight': 22},
#    {'source': 7583,
#     'target': 23972,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 7583,
#     'target': 25759,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 7583,
#     'target': 26933,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 7583, 'target': 27387, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 7583,
#     'target': 27480,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 7583,
#     'target': 27589,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 7743, 'target': 14, 'width': 0.41325739093091807, 'weight': 88},
#    {'source': 7743, 'target': 7583, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 7743,
#     'target': 10220,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 7743,
#     'target': 11315,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 7743,
#     'target': 12971,
#     'width': 0.19701273099093555,
#     'weight': 20},
#    {'source': 7743,
#     'target': 22283,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 7743,
#     'target': 34510,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 8123, 'target': 1928, 'width': 0.1461085517513561, 'weight': 11},
#    {'source': 8123, 'target': 5438, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8127, 'target': 1928, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 8127, 'target': 3585, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8127,
#     'target': 3620,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 8127, 'target': 3708, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 8127,
#     'target': 8127,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 8127,
#     'target': 9848,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 8127, 'target': 9861, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 8127,
#     'target': 10948,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 8127,
#     'target': 15354,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 8127,
#     'target': 15419,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 8127,
#     'target': 15420,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 8127,
#     'target': 22345,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 8127,
#     'target': 22363,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 8129, 'target': 1928, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 8129, 'target': 6264, 'width': 0.2888773697797899, 'weight': 43},
#    {'source': 8129,
#     'target': 18472,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 8129,
#     'target': 23896,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 8695, 'target': 429, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 8695, 'target': 4374, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8695,
#     'target': 12250,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 8695, 'target': 14661, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8695, 'target': 14687, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8695,
#     'target': 22095,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 8695,
#     'target': 25152,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 8695, 'target': 25751, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 8695, 'target': 32448, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 9803,
#     'target': 9900,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 9803,
#     'target': 30760,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 9879,
#     'target': 4374,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 9879, 'target': 9875, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 9879,
#     'target': 9897,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 9879,
#     'target': 11498,
#     'width': 0.19202425722778202,
#     'weight': 19},
#    {'source': 9879,
#     'target': 11848,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 9879,
#     'target': 16169,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 9879,
#     'target': 16561,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 9879,
#     'target': 22503,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 9879,
#     'target': 23624,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 9897,
#     'target': 4374,
#     'width': 0.20662869546545903,
#     'weight': 22},
#    {'source': 9897, 'target': 9834, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 9897,
#     'target': 9875,
#     'width': 0.22890810783562054,
#     'weight': 27},
#    {'source': 9897,
#     'target': 9879,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 9897, 'target': 9900, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 9897,
#     'target': 12155,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 9897,
#     'target': 12326,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 9897,
#     'target': 16576,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 9897, 'target': 19576, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 9897,
#     'target': 20797,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 9897,
#     'target': 22321,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 9897,
#     'target': 26881,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 9897,
#     'target': 27403,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 9897,
#     'target': 32505,
#     'width': 0.20662869546545903,
#     'weight': 22},
#    {'source': 9909, 'target': 4374, 'width': 0.2888773697797899, 'weight': 43},
#    {'source': 9909,
#     'target': 9875,
#     'width': 0.24527887203627102,
#     'weight': 31},
#    {'source': 9909, 'target': 11708, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 10884, 'target': 132, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 10884,
#     'target': 2162,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 10884,
#     'target': 3695,
#     'width': 0.25687317394632986,
#     'weight': 34},
#    {'source': 10884,
#     'target': 4355,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 10884,
#     'target': 5179,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 10884, 'target': 7583, 'width': 0.27511330672359, 'weight': 39},
#    {'source': 10884,
#     'target': 8696,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 10884,
#     'target': 10818,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 10884,
#     'target': 10884,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 10884,
#     'target': 10885,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 10884, 'target': 10898, 'width': 0.43163326751773, 'weight': 96},
#    {'source': 10884,
#     'target': 11318,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 10884,
#     'target': 12326,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10884,
#     'target': 13471,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 10884,
#     'target': 14951,
#     'width': 0.24129033187999907,
#     'weight': 30},
#    {'source': 10884,
#     'target': 19506,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10884,
#     'target': 20793,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 10884,
#     'target': 27338,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 10884,
#     'target': 27845,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 10884,
#     'target': 29806,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 10898,
#     'target': 5128,
#     'width': 0.2606233456578416,
#     'weight': 35},
#    {'source': 10898,
#     'target': 6264,
#     'width': 0.31460410238884706,
#     'weight': 51},
#    {'source': 10898,
#     'target': 10884,
#     'width': 0.34687670739726945,
#     'weight': 62},
#    {'source': 10898,
#     'target': 10893,
#     'width': 0.20662869546545903,
#     'weight': 22},
#    {'source': 10898,
#     'target': 28275,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 10898,
#     'target': 30132,
#     'width': 0.28549857085853186,
#     'weight': 42},
#    {'source': 10936, 'target': 14, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 10936, 'target': 3178, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 10936,
#     'target': 8678,
#     'width': 0.24527887203627102,
#     'weight': 31},
#    {'source': 10936,
#     'target': 9136,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 10936,
#     'target': 10937,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 10936,
#     'target': 11118,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 10936,
#     'target': 12316,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 10936,
#     'target': 13011,
#     'width': 0.19701273099093555,
#     'weight': 20},
#    {'source': 10936,
#     'target': 15110,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 10936,
#     'target': 15842,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10936,
#     'target': 17233,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10936,
#     'target': 18007,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10936,
#     'target': 18376,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 10936,
#     'target': 19646,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 10936,
#     'target': 20028,
#     'width': 0.22890810783562054,
#     'weight': 27},
#    {'source': 10936,
#     'target': 24428,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 10936,
#     'target': 24653,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 10936,
#     'target': 25487,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 10936,
#     'target': 26138,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 10936,
#     'target': 26882,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 11028,
#     'target': 1918,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11028, 'target': 3703, 'width': 0.224629074307532, 'weight': 26},
#    {'source': 11028,
#     'target': 6261,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 11028,
#     'target': 10872,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 11028,
#     'target': 14882,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11028,
#     'target': 15575,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11028,
#     'target': 19422,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 11268, 'target': 14, 'width': 0.19202425722778202, 'weight': 19},
#    {'source': 11268,
#     'target': 126,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 11268,
#     'target': 2281,
#     'width': 0.2606233456578416,
#     'weight': 35},
#    {'source': 11268,
#     'target': 3598,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11268,
#     'target': 3617,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 11268,
#     'target': 5128,
#     'width': 0.23310860696574337,
#     'weight': 28},
#    {'source': 11268,
#     'target': 8657,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11268, 'target': 10891, 'width': 0.27511330672359, 'weight': 39},
#    {'source': 11268,
#     'target': 11265,
#     'width': 0.224629074307532,
#     'weight': 26},
#    {'source': 11268,
#     'target': 16583,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11268,
#     'target': 22331,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11268,
#     'target': 36724,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11273, 'target': 14, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 11273,
#     'target': 5438,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11273,
#     'target': 10937,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 11273,
#     'target': 19485,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 11273,
#     'target': 24653,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 11273,
#     'target': 25259,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 11273,
#     'target': 26138,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11273,
#     'target': 26581,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 11273,
#     'target': 28615,
#     'width': 0.27861807612754325,
#     'weight': 40},
#    {'source': 11273,
#     'target': 28863,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 11273,
#     'target': 36802,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 11273,
#     'target': 38826,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 11315,
#     'target': 151,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 11315,
#     'target': 12967,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 11315,
#     'target': 13423,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 11315,
#     'target': 14230,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 11324,
#     'target': 5743,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11324, 'target': 6333, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 11324,
#     'target': 7583,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 11324,
#     'target': 16916,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11324,
#     'target': 17343,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 11324,
#     'target': 27387,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11325,
#     'target': 1928,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11325,
#     'target': 11273,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 11325,
#     'target': 19492,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11680, 'target': 14, 'width': 0.1648326767384268, 'weight': 14},
#    {'source': 11680,
#     'target': 122,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 11680,
#     'target': 151,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 11680, 'target': 154, 'width': 0.12460179159627961, 'weight': 8},
#    {'source': 11680, 'target': 190, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 11680, 'target': 429, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 11680, 'target': 573, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 11680,
#     'target': 3704,
#     'width': 0.28549857085853186,
#     'weight': 42},
#    {'source': 11680,
#     'target': 3736,
#     'width': 0.23310860696574337,
#     'weight': 28},
#    {'source': 11680,
#     'target': 7580,
#     'width': 0.2530674350536554,
#     'weight': 33},
#    {'source': 11680,
#     'target': 8628,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11680,
#     'target': 10912,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 11680,
#     'target': 11315,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 11680,
#     'target': 11498,
#     'width': 0.36593490649997884,
#     'weight': 69},
#    {'source': 11680,
#     'target': 11681,
#     'width': 0.39892037589884727,
#     'weight': 82},
#    {'source': 11680,
#     'target': 11784,
#     'width': 0.24920358319255922,
#     'weight': 32},
#    {'source': 11680,
#     'target': 12316,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 11680,
#     'target': 12970,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 11680,
#     'target': 12972,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 11680,
#     'target': 16179,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 11680,
#     'target': 16561,
#     'width': 0.47854226084828677,
#     'weight': 118},
#    {'source': 11680,
#     'target': 19470,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 11680,
#     'target': 19492,
#     'width': 0.215816633758865,
#     'weight': 24},
#    {'source': 11680,
#     'target': 19755,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 11680,
#     'target': 19777,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 12316,
#     'target': 2912,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 12316,
#     'target': 7580,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 12316,
#     'target': 10891,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 12316,
#     'target': 10936,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 12316,
#     'target': 11680,
#     'width': 0.2987845999993398,
#     'weight': 46},
#    {'source': 12316,
#     'target': 11708,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 12316,
#     'target': 12332,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 12316,
#     'target': 12971,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 12316,
#     'target': 19756,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 12316,
#     'target': 24432,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 12972,
#     'target': 122,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 12972, 'target': 833, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 12972, 'target': 1928, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 12972,
#     'target': 3703,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 12972,
#     'target': 6264,
#     'width': 0.21127261677364328,
#     'weight': 23},
#    {'source': 12972,
#     'target': 8695,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 12972,
#     'target': 10946,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 12972,
#     'target': 11315,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 12972,
#     'target': 11319,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 12972,
#     'target': 11680,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 12972,
#     'target': 11784,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 12972,
#     'target': 11820,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 12972,
#     'target': 12971,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 12972,
#     'target': 12975,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 12972,
#     'target': 16561,
#     'width': 0.17621354357144456,
#     'weight': 16},
#    {'source': 12972,
#     'target': 19574,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 12972,
#     'target': 27443,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 12991,
#     'target': 6264,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 12991,
#     'target': 11315,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 12991,
#     'target': 11321,
#     'width': 0.21127261677364328,
#     'weight': 23},
#    {'source': 12991,
#     'target': 13008,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 12991,
#     'target': 13423,
#     'width': 0.18163676320236147,
#     'weight': 17},
#    {'source': 12991,
#     'target': 16580,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 12997,
#     'target': 12997,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 14095,
#     'target': 1212,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 14095,
#     'target': 1917,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 14095,
#     'target': 2744,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 14095,
#     'target': 5090,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 14095,
#     'target': 5093,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 14095,
#     'target': 5423,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 14095,
#     'target': 7580,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 14095,
#     'target': 8400,
#     'width': 0.13930903806377162,
#     'weight': 10},
#    {'source': 14095,
#     'target': 14218,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 14095,
#     'target': 14881,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 14095,
#     'target': 14882,
#     'width': 0.30201479765963585,
#     'weight': 47},
#    {'source': 14095,
#     'target': 15839,
#     'width': 0.3915550585567777,
#     'weight': 79},
#    {'source': 14095,
#     'target': 19352,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 14095,
#     'target': 31461,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 14685,
#     'target': 3600,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 14685,
#     'target': 15582,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 14685,
#     'target': 26138,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 16561, 'target': 14, 'width': 0.24527887203627102, 'weight': 31},
#    {'source': 16561, 'target': 126, 'width': 0.2987845999993398, 'weight': 46},
#    {'source': 16561, 'target': 154, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 16561,
#     'target': 190,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 16561, 'target': 3704, 'width': 0.1321601576785834, 'weight': 9},
#    {'source': 16561,
#     'target': 3736,
#     'width': 0.23310860696574337,
#     'weight': 28},
#    {'source': 16561,
#     'target': 5108,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 16561,
#     'target': 5181,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 16561,
#     'target': 5570,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 16561,
#     'target': 8628,
#     'width': 0.44491738837652134,
#     'weight': 102},
#    {'source': 16561, 'target': 9879, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 16561,
#     'target': 11498,
#     'width': 0.27156330887614916,
#     'weight': 38},
#    {'source': 16561,
#     'target': 11680,
#     'width': 0.5042140477316346,
#     'weight': 131},
#    {'source': 16561,
#     'target': 11683,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 16561,
#     'target': 11784,
#     'width': 0.3551697517535057,
#     'weight': 65},
#    {'source': 16561,
#     'target': 12970,
#     'width': 0.22026692946430568,
#     'weight': 25},
#    {'source': 16561,
#     'target': 12971,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 16561,
#     'target': 12972,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 16561,
#     'target': 13471,
#     'width': 0.15883674169451276,
#     'weight': 13},
#    {'source': 16561,
#     'target': 16562,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 16561,
#     'target': 16576,
#     'width': 0.24920358319255922,
#     'weight': 32},
#    {'source': 16561,
#     'target': 17101,
#     'width': 0.7211850086569952,
#     'weight': 268},
#    {'source': 16561,
#     'target': 19470,
#     'width': 0.30521081044749404,
#     'weight': 48},
#    {'source': 16561,
#     'target': 19755,
#     'width': 0.3496629104486151,
#     'weight': 63},
#    {'source': 16561,
#     'target': 19777,
#     'width': 0.20187797547313593,
#     'weight': 21},
#    {'source': 16561,
#     'target': 22277,
#     'width': 0.15260540522374702,
#     'weight': 12},
#    {'source': 16561,
#     'target': 26853,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 19062, 'target': 14, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 19062, 'target': 1904, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 19062, 'target': 9708, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 19062,
#     'target': 15894,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 20797, 'target': 7920, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 20797,
#     'target': 8885,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 20797,
#     'target': 9897,
#     'width': 0.1648326767384268,
#     'weight': 14},
#    {'source': 20797,
#     'target': 19528,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 20797,
#     'target': 24361,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 20797,
#     'target': 36811,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 22149, 'target': 151, 'width': 0.1079083168794325, 'weight': 6},
#    {'source': 22149, 'target': 152, 'width': 0.09850636549546778, 'weight': 5},
#    {'source': 22149, 'target': 441, 'width': 0.11655430348287169, 'weight': 7},
#    {'source': 22149,
#     'target': 8447,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 22149,
#     'target': 13517,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 22149,
#     'target': 15302,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 22149,
#     'target': 26194,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 22149,
#     'target': 26768,
#     'width': 0.19701273099093555,
#     'weight': 20},
#    {'source': 22149,
#     'target': 27369,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 24369,
#     'target': 27800,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 25380,
#     'target': 14974,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 25380,
#     'target': 25282,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 25672,
#     'target': 3732,
#     'width': 0.1461085517513561,
#     'weight': 11},
#    {'source': 25672,
#     'target': 8703,
#     'width': 0.2643203153571668,
#     'weight': 36},
#    {'source': 25672,
#     'target': 14959,
#     'width': 0.1079083168794325,
#     'weight': 6},
#    {'source': 25672,
#     'target': 22095,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 25672,
#     'target': 31056,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 25672,
#     'target': 32064,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 25672,
#     'target': 36802,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 25988,
#     'target': 10468,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 25988,
#     'target': 27293,
#     'width': 0.11655430348287169,
#     'weight': 7},
#    {'source': 25988,
#     'target': 27300,
#     'width': 0.1321601576785834,
#     'weight': 9},
#    {'source': 26138,
#     'target': 8136,
#     'width': 0.17621354357144456,
#     'weight': 16},
#    {'source': 26138,
#     'target': 8678,
#     'width': 0.17061802990709993,
#     'weight': 15},
#    {'source': 26138,
#     'target': 10117,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 26138,
#     'target': 10789,
#     'width': 0.09850636549546778,
#     'weight': 5},
#    {'source': 26138,
#     'target': 10936,
#     'width': 0.1869026873944194,
#     'weight': 18},
#    {'source': 26138,
#     'target': 10937,
#     'width': 0.12460179159627961,
#     'weight': 8},
#    {'source': 26138,
#     'target': 11273,
#     'width': 0.11655430348287169,
# ...
#     'color': '#302e8a'},
#    {'id': 5052,
#     'x': 1487.4302747419104,
#     'y': -331.8619653101655,
#     'x_canvas': 517.086054948382,
#     'y_canvas': 153.22760693796695,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 6254,
#     'x': 944.0071022685655,
#     'y': -66.80838457636612,
#     'x_canvas': 408.40142045371306,
#     'y_canvas': 206.2383230847268,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 9770,
#     'x': 908.0590401466953,
#     'y': 15.911994676623008,
#     'x_canvas': 401.21180802933907,
#     'y_canvas': 222.78239893532464,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 16547,
#     'x': 77.3317350285694,
#     'y': 452.5863207074834,
#     'x_canvas': 235.0663470057139,
#     'y_canvas': 310.11726414149666,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 369,
#     'x': 1053.9531123475513,
#     'y': 903.2557887674416,
#     'x_canvas': 430.39062246951016,
#     'y_canvas': 400.2511577534883,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 682,
#     'x': 1100.7352970129552,
#     'y': 454.8442769455235,
#     'x_canvas': 439.747059402591,
#     'y_canvas': 310.56885538910467,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 6317,
#     'x': 1194.132140941812,
#     'y': 502.29248428953156,
#     'x_canvas': 458.42642818836225,
#     'y_canvas': 320.0584968579063,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 388,
#     'x': 607.0878932011199,
#     'y': 13.265021741951431,
#     'x_canvas': 341.017578640224,
#     'y_canvas': 222.2530043483903,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 1762,
#     'x': 1337.5378021277095,
#     'y': -197.04116806806928,
#     'x_canvas': 487.1075604255418,
#     'y_canvas': 180.19176638638618,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 5609,
#     'x': 623.6612168009211,
#     'y': -89.3715135299096,
#     'x_canvas': 344.3322433601842,
#     'y_canvas': 201.72569729401812,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 5610,
#     'x': 501.0031620120826,
#     'y': 109.73816402370376,
#     'x_canvas': 319.8006324024165,
#     'y_canvas': 241.54763280474077,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 7179,
#     'x': 434.94748374983044,
#     'y': -44.66897139418727,
#     'x_canvas': 306.5894967499661,
#     'y_canvas': 210.66620572116258,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 29264,
#     'x': 262.1764721534282,
#     'y': 154.72005148810686,
#     'x_canvas': 272.03529443068567,
#     'y_canvas': 250.54401029762138,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 47120,
#     'x': 1434.2454997692512,
#     'y': 1010.8828892091341,
#     'x_canvas': 506.4490999538501,
#     'y_canvas': 421.7765778418268,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 28141,
#     'x': 944.1387655957042,
#     'y': 807.662405036368,
#     'x_canvas': 408.4277531191408,
#     'y_canvas': 381.13248100727355,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 377,
#     'x': 330.06373464234264,
#     'y': 19.116445301577873,
#     'x_canvas': 285.61274692846854,
#     'y_canvas': 223.4232890603156,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 378,
#     'x': 956.4660450644074,
#     'y': -696.3056079740132,
#     'x_canvas': 410.8932090128814,
#     'y_canvas': 80.33887840519742,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 380,
#     'x': 99.84546685313038,
#     'y': -41.7083348588564,
#     'x_canvas': 239.5690933706261,
#     'y_canvas': 211.25833302822875,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 381,
#     'x': 1368.0199200399832,
#     'y': 147.88717089325414,
#     'x_canvas': 493.20398400799655,
#     'y_canvas': 249.17743417865083,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 389,
#     'x': 593.4703807558295,
#     'y': 78.54230947966353,
#     'x_canvas': 338.2940761511659,
#     'y_canvas': 235.30846189593274,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 393,
#     'x': 850.7357793736576,
#     'y': -592.8264387050065,
#     'x_canvas': 389.74715587473145,
#     'y_canvas': 101.0347122589988,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 404,
#     'x': 117.81254193822772,
#     'y': -310.2068542792716,
#     'x_canvas': 243.16250838764557,
#     'y_canvas': 157.55862914414573,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 407,
#     'x': -46.56934532111981,
#     'y': 188.7710109665957,
#     'x_canvas': 210.28613093577607,
#     'y_canvas': 257.35420219331917,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 411,
#     'x': 197.37521849786012,
#     'y': -289.2248309939216,
#     'x_canvas': 259.075043699572,
#     'y_canvas': 161.75503380121572,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 412,
#     'x': -70.57096847535264,
#     'y': 136.95450535169547,
#     'x_canvas': 205.4858063049295,
#     'y_canvas': 246.9909010703391,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 4470,
#     'x': 959.2255453522394,
#     'y': -213.00617409559882,
#     'x_canvas': 411.4451090704478,
#     'y_canvas': 176.99876518088027,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 1263,
#     'x': 176.0965830518989,
#     'y': 13.908084799449624,
#     'x_canvas': 254.8193166103798,
#     'y_canvas': 222.38161695988995,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 2912,
#     'x': -59.630011391356376,
#     'y': 889.4658197984505,
#     'x_canvas': 207.67399772172877,
#     'y_canvas': 397.49316395969004,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 5179,
#     'x': 213.57847681842082,
#     'y': 869.257324066275,
#     'x_canvas': 262.3156953636842,
#     'y_canvas': 393.4514648132549,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 19767,
#     'x': -392.61452364116843,
#     'y': 811.4020151584206,
#     'x_canvas': 141.07709527176638,
#     'y_canvas': 381.88040303168407,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 22341,
#     'x': -359.804843278291,
#     'y': 834.7622484681273,
#     'x_canvas': 147.63903134434184,
#     'y_canvas': 386.55244969362536,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 26411,
#     'x': -337.2755790199843,
#     'y': 553.3314422496011,
#     'x_canvas': 152.1448841960032,
#     'y_canvas': 330.2662884499202,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 416,
#     'x': 620.5122722369541,
#     'y': -15.649767520228268,
#     'x_canvas': 343.7024544473908,
#     'y_canvas': 216.47004649595436,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 494,
#     'x': 975.4703078318516,
#     'y': 130.077535848945,
#     'x_canvas': 414.69406156637024,
#     'y_canvas': 245.615507169789,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11753,
#     'x': 393.12295102289045,
#     'y': -59.21612359362126,
#     'x_canvas': 298.2245902045781,
#     'y_canvas': 207.75677528127576,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 12818,
#     'x': 239.98907975685876,
#     'y': -819.5143942376103,
#     'x_canvas': 267.59781595137173,
#     'y_canvas': 55.69712115247802,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 375,
#     'x': 668.3443334378985,
#     'y': 122.46945858451576,
#     'x_canvas': 353.2688666875797,
#     'y_canvas': 244.09389171690316,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 382,
#     'x': 460.1853861374419,
#     'y': -144.54296145049446,
#     'x_canvas': 311.63707722748836,
#     'y_canvas': 190.69140770990114,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 418,
#     'x': 217.65610986485143,
#     'y': -150.5023132916778,
#     'x_canvas': 263.1312219729703,
#     'y_canvas': 189.49953734166448,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 1260,
#     'x': 272.99503940240675,
#     'y': -65.8938776666057,
#     'x_canvas': 274.19900788048136,
#     'y_canvas': 206.4212244666789,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 1264,
#     'x': 305.6789015676753,
#     'y': -125.43339870671254,
#     'x_canvas': 280.7357803135351,
#     'y_canvas': 194.51332025865753,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 1267,
#     'x': 358.7015034675919,
#     'y': -19.980604756547503,
#     'x_canvas': 291.3403006935184,
#     'y_canvas': 215.60387904869052,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 2672,
#     'x': 599.0200770253829,
#     'y': -278.7035261841381,
#     'x_canvas': 339.4040154050765,
#     'y_canvas': 163.85929476317241,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 4159,
#     'x': -132.30496475157895,
#     'y': -22.266449800843485,
#     'x_canvas': 193.13900704968424,
#     'y_canvas': 215.14671003983133,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 4168,
#     'x': 16.20748462071835,
#     'y': 219.70517319673456,
#     'x_canvas': 222.84149692414368,
#     'y_canvas': 263.5410346393469,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 6126,
#     'x': 224.5732803388352,
#     'y': -202.9453762714907,
#     'x_canvas': 264.514656067767,
#     'y_canvas': 179.0109247457019,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8749,
#     'x': 503.5094654873427,
#     'y': 195.21939430308927,
#     'x_canvas': 320.3018930974685,
#     'y_canvas': 258.64387886061786,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8944,
#     'x': -89.38485210699803,
#     'y': -382.85435335073834,
#     'x_canvas': 201.72302957860043,
#     'y_canvas': 143.02912932985237,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8959,
#     'x': 664.5673278166201,
#     'y': 486.0599182614705,
#     'x_canvas': 352.51346556332396,
#     'y_canvas': 316.8119836522941,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8967,
#     'x': 88.64836889873413,
#     'y': 112.38050921359792,
#     'x_canvas': 237.32967377974683,
#     'y_canvas': 242.0761018427196,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 9159,
#     'x': 199.93351523405886,
#     'y': -8.943333634084128,
#     'x_canvas': 259.58670304681175,
#     'y_canvas': 217.8113332731832,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 9652,
#     'x': 808.2294917705689,
#     'y': 14.895644914389829,
#     'x_canvas': 381.2458983541137,
#     'y_canvas': 222.579128982878,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 9660,
#     'x': -121.59276882771893,
#     'y': -593.3582162361346,
#     'x_canvas': 195.28144623445624,
#     'y_canvas': 100.92835675277315,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11559,
#     'x': 438.222627433892,
#     'y': -305.8124808630549,
#     'x_canvas': 307.2445254867784,
#     'y_canvas': 158.43750382738907,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11651,
#     'x': 209.81923121738922,
#     'y': -394.2943516781785,
#     'x_canvas': 261.5638462434778,
#     'y_canvas': 140.74112966436434,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 13431,
#     'x': -20.93714060397581,
#     'y': -251.50859053841364,
#     'x_canvas': 215.41257187920488,
#     'y_canvas': 169.29828189231733,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8850,
#     'x': 519.9833680404051,
#     'y': -806.3170342087757,
#     'x_canvas': 323.596673608081,
#     'y_canvas': 58.33659315824494,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8938,
#     'x': 815.8171946474595,
#     'y': -617.4259757563275,
#     'x_canvas': 382.7634389294918,
#     'y_canvas': 96.11480484873456,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11636,
#     'x': 214.06276608143182,
#     'y': -707.0535815313674,
#     'x_canvas': 262.41255321628637,
#     'y_canvas': 78.1892836937266,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11848,
#     'x': 281.32774268663854,
#     'y': -524.8154348070486,
#     'x_canvas': 275.8655485373277,
#     'y_canvas': 114.63691303859034,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 14653,
#     'x': 665.8952290201279,
#     'y': -431.439233863011,
#     'x_canvas': 352.77904580402554,
#     'y_canvas': 133.31215322739786,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 15029,
#     'x': 947.9311833126442,
#     'y': -670.4584626800281,
#     'x_canvas': 409.1862366625288,
#     'y_canvas': 85.50830746399444,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 16555,
#     'x': 213.33949429963874,
#     'y': -768.916100890636,
#     'x_canvas': 262.26789885992775,
#     'y_canvas': 65.8167798218729,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 4163,
#     'x': 588.8045499909485,
#     'y': -754.2672325620777,
#     'x_canvas': 337.36090999818964,
#     'y_canvas': 68.74655348758455,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 4741,
#     'x': 21.404063348193795,
#     'y': -329.11750410073563,
#     'x_canvas': 223.88081266963877,
#     'y_canvas': 153.77649917985292,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8096,
#     'x': -35.533948628715336,
#     'y': -411.9877148993188,
#     'x_canvas': 212.49321027425697,
#     'y_canvas': 137.2024570201363,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 8540,
#     'x': 871.1461960586629,
#     'y': -366.2927544184744,
#     'x_canvas': 393.82923921173256,
#     'y_canvas': 146.34144911630517,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11735,
#     'x': -108.72403050851135,
#     'y': -208.38846843847915,
#     'x_canvas': 197.85519389829776,
#     'y_canvas': 177.92230631230422,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 11840,
#     'x': 505.06632209883037,
#     'y': -448.34412619062743,
#     'x_canvas': 320.61326441976604,
#     'y_canvas': 129.93117476187456,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 14351,
#     'x': 87.04225227742857,
#     'y': -547.6184196690955,
#     'x_canvas': 237.00845045548573,
#     'y_canvas': 110.07631606618098,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 15931,
#     'x': 183.76041956979535,
#     'y': -31.92250688630413,
#     'x_canvas': 256.35208391395906,
#     'y_canvas': 213.2154986227392,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 20024,
#     'x': -133.8615189723414,
#     'y': -93.83985120496297,
#     'x_canvas': 192.82769620553177,
#     'y_canvas': 200.83202975900744,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 6510,
#     'x': 1296.4204284237471,
#     'y': -182.85608080276302,
#     'x_canvas': 478.8840856847493,
#     'y_canvas': 183.02878383944744,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 6775,
#     'x': 1163.0097472034756,
#     'y': -518.3244599363026,
#     'x_canvas': 452.2019494406951,
#     'y_canvas': 115.93510801273956,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    {'id': 7450,
#     'x': 1497.5988798493106,
#     'y': -256.123862945133,
#     'x_canvas': 519.1197759698621,
#     'y_canvas': 168.37522741097345,
#     'radius': 0.9999999999999998,
#     'color': '#302e8a'},
#    ...]},
#  {'zoom': 0.6,
#   'node_charge': -40.8279496288921,
#   'node_gravity': 0.1,
#   'link_distance': 15,
#   'link_distance_variation': 0,
#   'node_collision': True,
#   'wiggle_nodes': True,
#   'freeze_nodes': False,
#   'node_fill_color': '#302e8a',
#   'node_stroke_color': '#555555',
#   'node_label_color': '#000000',
#   'display_node_labels': False,
#   'scale_node_size_by_strength': False,
#   'node_size': 5,
#   'node_stroke_width': 0.47187556571325123,
#   'node_size_variation': 0.5,
#   'link_color': '#7c7c7c',
#   'link_width': 2,
#   'link_alpha': 0.5,
#   'link_width_variation': 0.5,
#   'display_singleton_nodes': True,
#   'min_link_weight_percentile': 0,
#   'max_link_weight_percentile': 1})
